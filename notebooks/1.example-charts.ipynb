# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.stats.api as sms
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
sns.set()

# %%
points = pd.read_csv('../data/results/points.csv')
results = pd.read_csv('../data/results/results.csv')

# %%
points.head(10)
# Out:
#           x          y         z     time    theta1    theta2    theta3  \
# 0  0.000068  10.000007 -0.000097  0.00000  1.570790 -0.613170  2.453449
# 1  0.000271  10.000029 -0.000389  0.01002  1.570769 -0.613178  2.453358
# 2  0.000609  10.000065 -0.000874  0.02004  1.570735 -0.613192  2.453208
# 3  0.001080  10.000116 -0.001552  0.03006  1.570688 -0.613211  2.452998
# 4  0.001684  10.000181 -0.002424  0.04008  1.570628 -0.613236  2.452728
# 5  0.002420  10.000261 -0.003488  0.05010  1.570554 -0.613266  2.452400
# 6  0.003288  10.000356 -0.004746  0.06012  1.570468 -0.613301  2.452013
# 7  0.004286  10.000466 -0.006198  0.07014  1.570368 -0.613342  2.451567
# 8  0.005414  10.000592 -0.007846  0.08016  1.570255 -0.613388  2.451064
# 9  0.006671  10.000733 -0.009690  0.09018  1.570129 -0.613439  2.450504
#
#      theta4    theta5
# 0  1.301222  1.570672
# 1  1.301046  1.570301
# 2  1.300753  1.569685
# 3  1.300345  1.568825
# 4  1.299822  1.567722
# 5  1.299185  1.566379
# ...

# %%
results.head(10)
# Out:
#      distance
# 0  122.369538
# 1   45.960089
# 2   45.960089
# 3   45.960089
# 4   39.312742
# 5   39.312742
# 6   39.312742
# 7   39.312742
# 8   39.312742
# 9   39.312742

# %%
plt.plot(points['time'], 180*points['theta1']/np.pi, label = 'Polinomy')
plt.xlabel('time')
plt.ylabel('Angle 1 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(points['time'], 180*points['theta2']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 2 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(points['time'], 180*points['theta3']/np.pi, label='Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 3 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(points['time'], 180*points['theta4']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 4 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(points['time'], 180*points['theta5']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 5 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(points['time'], points['x'], label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('X (cm)', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(points['time'], points['y'], label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Y (cm)', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
plt.plot(points['time'], points['z'], label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Z (cm)', labelpad=0)
plt.legend(loc='upper right')
plt.show()
