# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.stats.api as sms
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import seaborn as sns
sns.set()

# %%
points = pd.read_csv('../data/processed/points.csv')
results = pd.read_csv('../data/processed/results.csv')

# %%
points.head(10)
# Out:
#            x          y          z    theta1    theta2    theta3    theta4  \
# 0  10.000000  10.000000  10.000000  0.785398 -1.332611  2.196541  2.277662
# 1  10.018385  10.007057  10.027621  0.784832 -1.332566  2.193736  2.277372
# 2  10.070877  10.025748  10.105742  0.783153 -1.332426  2.185808  2.276509
# 3  10.153261  10.051949  10.227454  0.780384 -1.332183  2.173485  2.275087
# 4  10.261165  10.081220  10.385942  0.776553 -1.331829  2.157496  2.273120
# 5  10.390219  10.109068  10.574302  0.771684 -1.331356  2.138570  2.270622
# 6  10.536180  10.131158  10.785402  0.765803 -1.330758  2.117437  2.267605
# 7  10.695031  10.143493  11.011803  0.758937 -1.330024  2.094825  2.264084
# 8  10.863061  10.142544  11.245719  0.751110 -1.329149  2.071464  2.260072
# 9  11.036912  10.125335  11.479028  0.742349 -1.328124  2.048081  2.255583
#
#      theta5
# 0  2.356194
# 1  2.352042
# 2  2.339916
# 3  2.320311
# 4  2.293722
# 5  2.260645
# 6  2.221574
# 7  2.177006
# 8  2.127436
# 9  2.073358

# %%
results.head(10)
# Out:
#     distance
# 0  62.278505
# 1  58.098788
# 2  58.098788
# 3  58.098788
# 4  58.098788
# 5  58.098788
# 6  58.098788
# 7  58.098788
# 8  58.098788
# 9  58.098788

# %%
t = np.linspace(0,10,150)
plt.plot(t, 180*points['theta1']/np.pi, label = 'Polinomy')
plt.xlabel('time')
plt.ylabel('Angle 1 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, 180*points['theta2']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 2 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, 180*points['theta3']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 3 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, 180*points['theta4']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 4 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, 180*points['theta5']/np.pi, label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Angle 5 - rad', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, points['x'], label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('X (cm)', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, points['y'], label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Y (cm)', labelpad=0)
plt.legend(loc='upper right')
plt.show()

# %%
t = np.linspace(0,10,150)
plt.plot(t, points['z'], label = 'Genetic Algorithm')
plt.xlabel('time')
plt.ylabel('Z (cm)', labelpad=0)
plt.legend(loc='upper right')
plt.show()
